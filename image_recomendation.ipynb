# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
dt = pd.read_csv("Data/amazon_reviews.csv")
print("Data Dimensions are: ", dt.shape)
print("Columns: ", dt.columns)
# Out:
# Data Dimensions are:  (551159, 14)
# Columns:  Index(['userName', 'verified', 'itemName', 'description', 'image', 'brand',
#        'feature', 'category', 'price', 'rating', 'reviewTime', 'summary',
#        'reviewText', 'vote'],
#       dtype='object')

# %%
dt.dropna(subset=['category'], axis=0, inplace=True)
print(dt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551159 entries, 0 to 551158
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   userName     551098 non-null  object
#  1   verified     551159 non-null  bool
#  2   itemName     551158 non-null  object
#  3   description  551151 non-null  object
#  4   image        551159 non-null  object
#  5   brand        547290 non-null  object
#  6   feature      551159 non-null  object
#  7   category     551159 non-null  object
#  8   price        476825 non-null  object
#  9   rating       551159 non-null  float64
#  10  reviewTime   551159 non-null  object
#  11  summary      550925 non-null  object
#  12  reviewText   550764 non-null  object
#  13  vote         551159 non-null  int64
# dtypes: bool(1), float64(1), int64(1), object(11)
# memory usage: 55.2+ MB
# None

# %%
data = pd.DataFrame(dt)

# %%
data['category'] = dt['category'].str.split("|").str[0].str.strip()

# %%
data['category'].unique()
# Out:
# array(['Prime_Pantry', 'Grocery_and_Gourmet_Food', 'Pet_Supplies',
#        'Arts_Crafts_and_Sewing', 'Office_Products',
#        'Cell_Phones_and_Accessories', 'Video_Games',
#        'Patio_Lawn_and_Garden', 'Software', 'Musical_Instruments',
#        'Industrial_and_Scientific', 'Luxury_Beauty', 'All_Beauty',
#        'AMAZON_FASHION', 'Digital_Music', 'Appliances'], dtype=object)

# %%
data = data.drop_duplicates()
data.head()
# Out:
#           userName  verified  \
# 0  Amazon Customer      True
# 1            Carla      True
# 2           Jaclyn      True
# 3     Christinne M     False
# 4            Sandy      True
#
#                                             itemName  \
# 0  Toblerone Swiss Milk Chocolate Bar, Crunchy Sa...
# 1  Prince of Peace Organic Tea, Oolong, 100 Tea Bags
# 2  Pet Champion Adjustable No-Pull Harness, Colla...
# 3  Koh-I-Noor Progresso Woodless Colored 24-Penci...
# 4  Parker Urban Premium Ebony Metal Chiseled, Bal...
#
#                                          description  \
# 0  ["Made from deliciously decadent ingredients, ...
# 1  ['Prince of Peace Enterprises, Inc., founded i...
# 2  ["The Pet Champion Large/ Extra Large 22-36 in...
# 3  ['Koh-I-Noor Progresso Woodless Colored 24-Pen...
# 4  ["Stunning craftsmanship based on a classic st...
#
#                                                image            brand  \
# ...

# %%
filter_products = """category == 'Pet_Supplies' or category == 'Grocery_and_Gourmet_Food' or category == 'Patio_Lawn_and_Garden' or category == 'Office_Products' or category == 'Cell_Phones_and_Accessories' or category == 'Arts_Crafts_and_Sewing' or category == 'Prime_Pantry' or category == 'Musical_Instruments' or category == 'Video_Games' or category == 'Industrial_and_Scientific' or category == 'Luxury_Beauty' or category == 'AMAZON_FASHION'"""

data = data.query(filter_products)

# %%
data.category.unique()
# Out:
# array(['Prime_Pantry', 'Grocery_and_Gourmet_Food', 'Pet_Supplies',
#        'Arts_Crafts_and_Sewing', 'Office_Products',
#        'Cell_Phones_and_Accessories', 'Video_Games',
#        'Patio_Lawn_and_Garden', 'Musical_Instruments',
#        'Industrial_and_Scientific', 'Luxury_Beauty', 'AMAZON_FASHION'],
#       dtype=object)

# %%
pd.DataFrame(data['category'].value_counts())
# Out:
#                              category
# Pet_Supplies                   170423
# Grocery_and_Gourmet_Food        95489
# Patio_Lawn_and_Garden           62528
# Office_Products                 55556
# Cell_Phones_and_Accessories     41887
# Arts_Crafts_and_Sewing          33886
# Prime_Pantry                    15290
# Musical_Instruments             14989
# Video_Games                     11754
# Industrial_and_Scientific        5777
# Luxury_Beauty                    1796
# AMAZON_FASHION                    481

# %%
data.shape
# Out:
# (509856, 14)

# %%
# a = data.loc[data['category']=='Toys & Games']
a = np.concatenate([data.loc[data['category']=='Pet_Supplies'][:500], 
                    data.loc[data['category']=='Grocery_and_Gourmet_Food'][:500], 
                    data.loc[data['category']=='Patio_Lawn_and_Garden'][:500], 
                    data.loc[data['category']=='Office_Products'][:500], 
                    data.loc[data['category']=='Cell_Phones_and_Accessories'][:500], 
                    data.loc[data['category']=='Arts_Crafts_and_Sewing'][:500], 
                    data.loc[data['category']=='Prime_Pantry'][:500], 
                    data.loc[data['category']=='Musical_Instruments'][:500], 
                    data.loc[data['category']=='Video_Games'][:500], 
                    data.loc[data['category']=='Industrial_and_Scientific'][:500], 
                    data.loc[data['category']=='Luxury_Beauty'][:500]])
b = ['userName', 'verified', 'itemName', 'description', 'image', 'brand',
       'feature', 'category', 'price', 'rating', 'reviewTime', 'summary',
       'reviewText', 'vote']
a = pd.DataFrame(a, columns = b)


a['image'] = a['image'].replace("[]", None)
a = a.dropna()
# a = a.drop(a.index[994:997], axis = 0) 
a.head(3)
# Out:
#    userName verified                                           itemName  \
# 0    Jaclyn     True  Pet Champion Adjustable No-Pull Harness, Colla...
# 2   patrick     True  Blue Buffalo Life Protection Formula Natural P...
# 3  Craig S.     True  Squishy Face Studio Flirt Pole V2 with Braided...
#
#                                          description  \
# 0  ["The Pet Champion Large/ Extra Large 22-36 in...
# 2  ['Because puppyhood is such an important stage...
# 3  ["Want An Easy Way To Keep Your Dog Happy And ...
#
#                                                image                brand  \
# 0  ['https://images-na.ssl-images-amazon.com/imag...         Pet Champion
# 2  ['https://images-na.ssl-images-amazon.com/imag...         Blue Buffalo
# 3  ['https://images-na.ssl-images-amazon.com/imag...  Squishy Face Studio
#
#                                              feature      category   price  \
# 0  ['Features Bright Pink Lemonade pattern', 'Dua...  Pet_Supplies   $7.99
# ...

# %%
a['image'].isna().value_counts()
# Out:
# False    3731
# Name: image, dtype: int64

# %%
a.category.unique()
# Out:
# array(['Pet_Supplies', 'Grocery_and_Gourmet_Food',
#        'Patio_Lawn_and_Garden', 'Office_Products',
#        'Cell_Phones_and_Accessories', 'Arts_Crafts_and_Sewing',
#        'Prime_Pantry', 'Musical_Instruments', 'Video_Games',
#        'Industrial_and_Scientific'], dtype=object)

# %%
a.describe()
# Out:
#                userName verified  \
# count              3731     3731
# unique             2133        2
# top     Amazon Customer     True
# freq                189     3441
#
#                                                  itemName description  \
# count                                                3731        3731
# unique                                               3258        2840
# top     AcuRite 00613 Humidity Monitor with Indoor The...          []
# freq                                                   10         420
#
#                                                     image  \
# count                                                3731
# unique                                               3226
# top     ['https://images-na.ssl-images-amazon.com/imag...
# freq                                                   30
#
#                          brand feature      category  \
# count                     3731    3731          3731
# ...

# %%
pd.DataFrame(a['category'].value_counts())
# Out:
#                              category
# Prime_Pantry                      453
# Pet_Supplies                      407
# Video_Games                       395
# Musical_Instruments               387
# Office_Products                   376
# Cell_Phones_and_Accessories       371
# Grocery_and_Gourmet_Food          348
# Industrial_and_Scientific         348
# Arts_Crafts_and_Sewing            331
# Patio_Lawn_and_Garden             315

# %%
a = a.reset_index()
a = a.rename(columns={"index": "id"})

# %%
d = list(a['id'])
print(len(d))
# e = list(a['image'])
# Out:
# 3731

# %%
if len(a) > 3731:
    mystring = a['image'][3731].split("'")[1]
e = []
for index, row in a.iterrows():
    mystring = row['image'].split("'")[1]
    e.append(mystring)

# %%
def img_array(img):   
    """
    This function takes in an image and converts the image to an array after resizing
  
    """
    response = urllib.request.urlopen(img)
    image = np.asarray(bytearray(response.read()), dtype="uint8") 
    image_bgr = cv2.imdecode(image, cv2.IMREAD_COLOR)
    image_bgr = cv2.resize(image_bgr, (224,224)) # resizing all images to one size 
    return image_bgr

# %%
a
# Out:
#         id              userName verified  \
# 0        0                Jaclyn     True
# 1        2               patrick     True
# 2        3              Craig S.     True
# 3        4           Super Sanne     True
# 4        5  Matthew Daviskavitch     True
# ...    ...                   ...      ...
# 3726  4988        Glenn Thompson     True
# 3727  4990        Glenn Thompson     True
# 3728  4991                   D.D    False
# 3729  4993              Snowmass     True
# 3730  4994        Danny in Texas     True
#
#                                                itemName  \
# 0     Pet Champion Adjustable No-Pull Harness, Colla...
# 1     Blue Buffalo Life Protection Formula Natural P...
# 2     Squishy Face Studio Flirt Pole V2 with Braided...
# 3                    Penn Plax Net Breeder for Aquarium
# 4     PetSafe Freedom Aluminum Patio Panel Sliding G...
# ...                                                 ...
# 3726  BIPEE 500ml Safety Wash Bottle, Narrow Mouth, ...
# ...

# %%
# Converting the response variable into numbers
a['category'][a['category']=='Prime_Pantry']=0
a['category'][a['category']=='Arts_Crafts_and_Sewing']=1
a['category'][a['category']=='Musical_Instruments']=2
a['category'][a['category']=='Industrial_and_Scientific']=3
a['category'][a['category']=='Video_Games']=4
a['category'][a['category']=='Office_Products']=5
a['category'][a['category']=='Patio_Lawn_and_Garden']=6
a['category'][a['category']=='Pet_Supplies']=7
a['category'][a['category']=='Cell_Phones_and_Accessories']=8
a['category'][a['category']=='Grocery_and_Gourmet_Food']=9
a['category']=a['category'].astype(int)
# Out:
# C:\Users\shimu\AppData\Local\Temp\ipykernel_312\2375973354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['category'][a['category']=='Prime_Pantry']=0
# C:\Users\shimu\AppData\Local\Temp\ipykernel_312\2375973354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['category'][a['category']=='Arts_Crafts_and_Sewing']=1
# C:\Users\shimu\AppData\Local\Temp\ipykernel_312\2375973354.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
h = np.array(a['category'])
h
# Out:
# array([7, 7, 7, ..., 3, 3, 3])

# %%
img_arr = ...  # Your assignment here
print(type(img_arr))
# Out:
# <class 'ellipsis'>
